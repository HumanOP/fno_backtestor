# %%
# Sample strategy: Buy ATM Call Option at the start of each table (day), hold till expiry
from backtesting_opt import _Data, Strategy, Backtest
import pandas as pd
import math
from datetime import datetime, date as DateObject # Added DateObject
iv = {}
class IV_Slope(Strategy):
    # Define parameters as class variables for optimization/flexibility
    iv_slope_thresholds: dict = None
    legs: dict = None
    iv: dict = None
    position_id= 0
    signal= 0
    

    def init(self):
        super().init()
        self.entry_type_dict = None
        print(legs)

    def next(self):
        super().next()
        if self.spot is None or pd.isna(self.spot):
            return
        atm = round(self.spot / 50) * 50

        for leg in self.legs.values():
            valid_tte = min(tte for tte in self.tte_to_expiry.keys() if any(lower <= tte <= upper for lower, upper in [leg["expiry_range"]]))
            leg["expiry"] = self.tte_to_expiry[valid_tte]

        for leg in self.legs.values():
            if leg["target_strike"] == "ATM":
                leg["strike"] = float(atm)
            contract = f"NIFTY{pd.Timestamp(leg['expiry']).strftime('%d%b%y').upper()}{int(leg['strike'])}{leg['type']}"
            leg["contract"] = contract
            leg["data"] = self._data.get_ticker_data(contract)

        missing_legs = [leg["contract"] for leg in self.legs.values() if leg["data"] is None]
        if missing_legs:
            print(f"IV not found for {self.time}. Spot: {self.spot} Missing legs: {missing_legs}")
            return
        
        # if (pd.Timestamp("15:29:00").time() <= pd.Timestamp(row.Index).time() <= pd.Timestamp("15:30:00").time()):
        iv_slope = math.log((self.legs["leg1"]["data"]["iv"] + self.legs["leg2"]["data"]["iv"]) / (self.legs["leg3"]["data"]["iv"] + self.legs["leg4"]["data"]["iv"]) ,10)
        # print(f"{self.spot}  {self.legs['leg1']['data']['iv']} {self.legs['leg2']['data']['iv']} {self.legs['leg3']['data']['iv']} {self.legs['leg4']['data']['iv']}")
        iv[self.time]=(iv_slope, self.spot)

        new_signal = (iv_slope > iv_slope_thresholds["upper_gamma"]) * 3 + (iv_slope_thresholds["upper_gamma"] >= iv_slope > iv_slope_thresholds["upper_buffer"]) * 2 + (iv_slope_thresholds["upper_buffer"] >= iv_slope > 0) * 1\
            + (0 >= iv_slope > iv_slope_thresholds["lower_buffer"]) * -1 + (iv_slope_thresholds["lower_buffer"] >= iv_slope > iv_slope_thresholds["lower_gamma"]) * -2 + (iv_slope_thresholds["lower_gamma"] >= iv_slope) * -3
        
        print(f"Signal: {self.signal}, new_signal: {new_signal} IV Slope: {iv_slope} Spot: {self.spot} Time: {self.time}")
        # print(f"New Signal: {new_signal} IV Slope: {iv_slope} Spot: {self.spot}")
        active_trades = self.active_trades

        if (not active_trades) and (pd.Timestamp(self.time).time() < pd.Timestamp("15:00:00").time()):
            if new_signal == -2 or new_signal == 2:         # No trade entry if buffer zone and no active position
                return
            elif new_signal == 1:
                self.entry_type_dict = {'weekly': 'BUY', 'monthly': 'SELL'}          # Original
                # entry_type_dict = {'weekly': 'SELL', 'monthly': 'BUY'}
                # continue
            elif new_signal == -1:
                self.entry_type_dict = {'weekly': 'SELL', 'monthly': 'BUY'}          # Original
                # entry_type_dict = {'weekly': 'BUY', 'monthly': 'SELL'}  
                # continue
            elif new_signal == -3 or new_signal == 3:
                self.entry_type_dict = {'weekly': 'BUY', 'monthly': None}          # Original
                # entry_type_dict = {'weekly': 'SELL', 'monthly': None}
                # continue
            
            placed_any_leg = False
            for leg_id, leg in self.legs.items():
                entry_type = self.entry_type_dict.get(leg["expiry_type"])
                order_fn = {'BUY': self.buy, 'SELL': self.sell}.get(entry_type)
                if order_fn is None:
                    continue

                order_fn(
                    strategy_id='strat1',
                    position_id=self.position_id,
                    leg_id=leg_id,
                    ticker=leg["contract"],
                    quantity=1,
                    stop_loss=None,
                    take_profit=None,
                    tag=f'{new_signal} signal entry'
                )
                placed_any_leg = True
            if placed_any_leg:
                self.position_id += 1
            
        else:
            # Exit if near expiry date is reached
            near_expiry = None
            for trade in active_trades:
                expiry = datetime.strptime(trade.ticker[-14:-7], "%d%b%y").date()
                near_expiry = expiry if near_expiry is None else min(near_expiry, expiry)
            exit_reason = (
                "Near Expiry reached" if (pd.Timestamp(self.time).date() == near_expiry) else
                "Signal changed" if (self.signal != new_signal) else
                None
            )
            if exit_reason:
                for trade in active_trades:
                    contract = trade.ticker
                    print("closing position")
                    trade.close(trade.size, tag=exit_reason)

            if self.signal == new_signal:
                leg_strike = self.legs["leg2"]["strike"]
                if (self.spot*0.99) <= leg_strike <= (self.spot*1.01):
                    # Case (a)
                    pass
                else:
                    # Case (b)
                    # take new ATM Calendar
                    placed_any_leg = False
                    for leg_id, leg in self.legs.items():
                        entry_type = self.entry_type_dict.get(leg["expiry_type"])
                        order_fn = {'BUY': self.buy, 'SELL': self.sell}.get(entry_type)
                        if order_fn is None:
                            continue

                        order_fn(
                            strategy_id='strat1',
                            position_id=self.position_id,
                            leg_id=leg_id,
                            ticker=leg["contract"],
                            quantity=1,
                            stop_loss=None,
                            take_profit=None,
                            tag=f'Adjustment Calendar'
                        )
                        placed_any_leg = True
                    if placed_any_leg:
                        self.position_id += 1

        self.signal = new_signal



# Run the backtest pipeline
if __name__ == "__main__":
    db_path = "nifty_1min_desiquant.duckdb"
    iv_slope_thresholds = {
        "upper_gamma": 0.15,
        "upper_buffer": 0.05,
        "lower_buffer": -0.10,
        "lower_gamma": -0.3
    }

    portfolio_sl = 0.01
    portfolio_tp = 0.03
    legs = {
        'leg1': {'type': 'CE', 'expiry_type': 'weekly', 'expiry_range': [12, 20], 'target_strike': 'ATM', 'stop_loss':None, 'take_profit':None},
        'leg2': {'type': 'PE', 'expiry_type': 'weekly', 'expiry_range': [12, 20], 'target_strike': 'ATM', 'stop_loss':None, 'take_profit':None},
        'leg3': {'type': 'CE', 'expiry_type': 'monthly', 'expiry_range': [26, 34], 'target_strike': 'ATM', 'stop_loss':None, 'take_profit':None},
        'leg4': {'type': 'PE', 'expiry_type': 'monthly', 'expiry_range': [26, 34], 'target_strike': 'ATM', 'stop_loss':None, 'take_profit':None}
        }
    bt = Backtest(
        db_path=db_path,
        strategy=IV_Slope,
        cash=10000000,
        commission_per_contract=0.65,
        option_multiplier=75
    )
    processed_orders, final_positions = bt.run(iv_slope_thresholds=iv_slope_thresholds, legs=legs)
    print("Processed Orders:", processed_orders)
    print("Final Positions:", final_positions)
    import pprint
    pprint.pprint(legs)
# Out:
# Initializing strategy...
# {'leg1': {'type': 'CE', 'expiry_type': 'weekly', 'expiry_range': [12, 20], 'target_strike': 'ATM', 'stop_loss': None, 'take_profit': None}, 'leg2': {'type': 'PE', 'expiry_type': 'weekly', 'expiry_range': [12, 20], 'target_strike': 'ATM', 'stop_loss': None, 'take_profit': None}, 'leg3': {'type': 'CE', 'expiry_type': 'monthly', 'expiry_range': [26, 34], 'target_strike': 'ATM', 'stop_loss': None, 'take_profit': None}, 'leg4': {'type': 'PE', 'expiry_type': 'monthly', 'expiry_range': [26, 34], 'target_strike': 'ATM', 'stop_loss': None, 'take_profit': None}}
# Backtesting Options Strategy:   0%|          | 0/3 [00:00<?, ?it/s]
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:15:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:16:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:17:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:18:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:19:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:20:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:21:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:22:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:23:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:24:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:25:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:26:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:27:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:28:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:29:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:30:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:31:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:32:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:33:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:34:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:35:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:36:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:37:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:38:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:39:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:40:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:41:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:42:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:43:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:44:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:45:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:46:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:47:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:48:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:49:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:50:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:51:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:52:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:53:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:54:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:55:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:56:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:57:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:58:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 09:59:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:00:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:01:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:02:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:03:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:04:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:05:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:06:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:07:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:08:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:09:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:10:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:11:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:12:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:13:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:14:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:15:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:16:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:17:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:18:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:19:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:20:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:21:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:22:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:23:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:24:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:25:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:26:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:27:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:28:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:29:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:30:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:31:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:32:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:33:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:34:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:35:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:36:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:37:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:38:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:39:59
# Processed nifty_2023_01_02 in 0.02 seconds at 2023-01-02 10:40:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:41:59
# Processed nifty_2023_01_02 in 0.01 seconds at 2023-01-02 10:42:59
# Processed nifty_2023_01_02 in 0.01 seconds at 2023-01-02 10:43:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:44:59
# Processed nifty_2023_01_02 in 0.02 seconds at 2023-01-02 10:45:59
# Processed nifty_2023_01_02 in 0.01 seconds at 2023-01-02 10:46:59
# Processed nifty_2023_01_02 in 0.01 seconds at 2023-01-02 10:47:59
# Processed nifty_2023_01_02 in 0.01 seconds at 2023-01-02 10:48:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:49:59
# Processed nifty_2023_01_02 in 0.00 seconds at 2023-01-02 10:50:59
# Processed nifty_2023_01_02 in 0.03 seconds at 2023-01-02 10:51:59
# Processed nifty_2023_01_02 in 0.01 seconds at 2023-01-02 10:52:59
# Processed nifty_2023_01_02 in 0.01 seconds at 2023-01-02 10:53:59
# Processed nifty_2023_01_02 in 0.02 seconds at 2023-01-02 10:54:59
# Processed nifty_2023_01_02 in 0.02 seconds at 2023-01-02 10:55:59
# Processed nifty_2023_01_02 in 0.02 seconds at 2023-01-02 10:56:59
# Processed nifty_2023_01_02 in 0.03 seconds at 2023-01-02 10:57:59
# Processed nifty_2023_01_02 in 0.02 seconds at 2023-01-02 10:58:59
# Processed nifty_2023_01_02 in 0.03 seconds at 2023-01-02 10:59:59
# Processed nifty_2023_01_02 in 0.02 seconds at 2023-01-02 11:00:59
# Processed nifty_2023_01_02 in 0.03 seconds at 2023-01-02 11:01:59
# Processed nifty_2023_01_02 in 0.03 seconds at 2023-01-02 11:02:59
# Processed nifty_2023_01_02 in 0.02 seconds at 2023-01-02 11:03:59
# Processed nifty_2023_01_02 in 0.02 seconds at 2023-01-02 11:04:59
# Processed nifty_2023_01_02 in 0.02 seconds at 2023-01-02 11:05:59
# Processed nifty_2023_01_02 in 0.02 seconds at 2023-01-02 11:06:59
# Processed nifty_2023_01_02 in 0.02 seconds at 2023-01-02
# Processed nifty_2023_01_03 in 0.68 seconds at 2023-01-03 12:47:59
# Processed nifty_2023_01_03 in 0.82 seconds at 2023-01-03 12:48:59
# Processed nifty_2023_01_03 in 0.64 seconds at 2023-01-03 12:49:59
# Processed nifty_2023_01_03 in 0.86 seconds at 2023-01-03 12:50:59
# Processed nifty_2023_01_03 in 0.72 seconds at 2023-01-03 12:51:59
# Processed nifty_2023_01_03 in 0.82 seconds at 2023-01-03 12:52:59
# Processed nifty_2023_01_03 in 0.71 seconds at 2023-01-03 12:53:59
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 160
#     147 legs = {
#     148     'leg1': {'type': 'CE', 'expiry_type': 'weekly', 'expiry_range': [12, 20], 'target_strike': 'ATM', 'stop_loss':None, 'take_profit':None},
#     149     'leg2': {'type': 'PE', 'expiry_type': 'weekly', 'expiry_range': [12, 20], 'target_strike': 'ATM', 'stop_loss':None, 'take_profit':None},
#     150     'leg3': {'type': 'CE', 'expiry_type': 'monthly', 'expiry_range': [26, 34], 'target_strike': 'ATM', 'stop_loss':None, 'take_profit':None},
#     151     'leg4': {'type': 'PE', 'expiry_type': 'monthly', 'expiry_range': [26, 34], 'target_strike': 'ATM', 'stop_loss':None, 'take_profit':None}
#     152     }
#     153 bt = Backtest(
#     154     db_path=db_path,
#     155     strategy=IV_Slope,
#    (...)
#     158     option_multiplier=75
#     159 )
# --> 160 processed_orders, final_positions = bt.run(iv_slope_thresholds=iv_slope_thresholds, legs=legs)
#     161 print("Processed Orders:", processed_orders)
#     162 print("Final Positions:", final_positions)
#
# File d:\My files\2 Cents Capital\fno_backtestor\backtesting_opt.py:842, in Backtest.run(self, **kwargs)
#     838         broker.handle_expirations(row.Index.date())  # Pass date part
#     840     start = time.time()
# --> 842     broker.next()  # This will call _process_orders
#     843     print(f"Processed {table} in {time.time() - start:.2f} seconds at {row.Index}")
#     845 except _OutOfMoneyError:
#
# File d:\My files\2 Cents Capital\fno_backtestor\backtesting_opt.py:671, in _Broker.next(self)
#     670 def next(self): # Called for each spot bar
# --> 671     self._process_orders()
#     673     # Log equity
#     674     self._equity[self.time] = self.equity()
#
# File d:\My files\2 Cents Capital\fno_backtestor\backtesting_opt.py:698, in _Broker._process_orders(self)
#     691 if order not in self.orders: continue # Already processed/canceled
#     693 # Option orders are typically GTD (Good 'Til Day) or GTC.
#     694 # For simplicity, assume orders persist until filled/canceled or end of day.
#     695 # More realistically, unfilled day orders would be canceled by EOD.
#     696 # Here, we process against the current options_data snapshot.
# --> 698 exec_price = self.get_ticker_execution_price(order.ticker, order.is_long)
#     700 if exec_price is None:
#     701     # print(f"Order for {order.ticker} ({order.size} @ LMT {order.limit}) could not fill at current market.")
#     702     # In a real system, unfilled limit orders might persist.
#     703     # For this backtester, if it doesn't fill on this "tick" (daily snapshot), it waits.
#     704     # User might need to cancel it via strategy logic.
#     705     continue
#
# File d:\My files\2 Cents Capital\fno_backtestor\backtesting_opt.py:542, in _Broker.get_ticker_execution_price(self, ticker, is_buy_order)
#     536 def get_ticker_execution_price(self, ticker: str, is_buy_order: bool) -> Optional[float]:
#     537     """
#     538     Determines execution price for an option.
#     539     Simple logic: if limit, use limit if marketable. Else, use 'Last' or 'Mid'.
#     540     A real system uses NBBO and considers liquidity.
#     541     """
# --> 542     ticker_data = self.get_ticker_details(ticker)
#     543     if ticker_data is None:
#     544         # warnings.warn(f"No data for option {ticker} in current chain. Order cannot fill.")
#     545         return None
#
# File d:\My files\2 Cents Capital\fno_backtestor\backtesting_opt.py:534, in _Broker.get_ticker_details(self, ticker)
#     533 def get_ticker_details(self, ticker: str) -> Optional[pd.Series]:
# --> 534     return self._data.get_ticker_data(ticker)
#
# File d:\My files\2 Cents Capital\fno_backtestor\backtesting_opt.py:69, in _Data.get_ticker_data(self, ticker)
#      65 def get_ticker_data(self, ticker: str) -> Optional[pd.DataFrame]:
#      66     # 1. Need to add a cache for this
#      67     # 2. Need to check the data directly at that time and if not available then do the following
#      68     subset_df = self._ticker_map.get(ticker, self._data_df_template)
# ---> 69     asof_time = subset_df.index.asof(self._time) if not subset_df.empty else None
#      70     if pd.isna(asof_time):
#      71         return None
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:5478, in Index.asof(self, label)
#    5421 @final
#    5422 def asof(self, label):
#    5423     """
#    5424     Return the label from the index, or, if not present, the previous one.
#    5425
#    (...)
#    5476     ValueError: index must be monotonic increasing or decreasing
#    5477     """
# -> 5478     self._searchsorted_monotonic(label)  # validate sortedness
#    5479     try:
#    5480         loc = self.get_loc(label)
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:6409, in Index._searchsorted_monotonic(self, label, side)
#    6407 def _searchsorted_monotonic(self, label, side: Literal["left", "right"] = "left"):
#    6408     if self.is_monotonic_increasing:
# -> 6409         return self.searchsorted(label, side=side)
#    6410     elif self.is_monotonic_decreasing:
#    6411         # np.searchsorted expects ascending sort order, have to reverse
#    6412         # everything for it to work (element ordering, search side and
#    6413         # resulting value).
#    6414         pos = self[::-1].searchsorted(
#    6415             label, side="right" if side == "left" else "left"
#    6416         )
#
# File c:\Python311\Lib\site-packages\pandas\core\base.py:1321, in IndexOpsMixin.searchsorted(self, value, side, sorter)
#    1318 values = self._values
#    1319 if not isinstance(values, np.ndarray):
#    1320     # Going through EA.searchsorted directly improves performance GH#38083
# -> 1321     return values.searchsorted(value, side=side, sorter=sorter)
#    1323 return algorithms.searchsorted(
#    1324     values,
#    1325     value,
#    1326     side=side,
#    1327     sorter=sorter,
#    1328 )
#
# File c:\Python311\Lib\site-packages\pandas\core\arrays\_mixins.py:238, in NDArrayBackedExtensionArray.searchsorted(self, value, side, sorter)
#     230 @doc(ExtensionArray.searchsorted)
#     231 def searchsorted(
#     232     self,
#    (...)
#     235     sorter: NumpySorter = None,
#     236 ) -> npt.NDArray[np.intp] | np.intp:
#     237     npvalue = self._validate_setitem_value(value)
# --> 238     return self._ndarray.searchsorted(npvalue, side=side, sorter=sorter)
#
# KeyboardInterrupt:
